# %%
#Name : Shreya Das
#College : National Institute of Technolog,Durgapur

# %%
#Text to Speech Conversion

####!pip install gTTS

from gtts import gTTS  # This module is imported so that we can. # play the converted audio
test=input('enter the text :') # Taking input from the user & storing it in test
tts=gTTS(text=test,lang='hi') # Converting the input text to speech , language - English
tts.save('python20july.mp3') # Saving the audio file

# %%
# !pip install pyttsx3
import pyttsx3
engine = pyttsx3.init()
engine.say("Good morning")
engine.runAndWait()

# %%
import pyttsx3
engine = pyttsx3.init() # object creation

""" RATE"""
rate = engine.getProperty('rate')   # getting details of current speaking rate
print (rate)                        #printing current voice rate
engine.setProperty('rate',155)     # setting up new voice rate


"""VOLUME"""
volume = engine.getProperty('volume')   #getting to know current volume level (min=0 and max=1)
print (volume)                          #printing current volume level
engine.setProperty('volume',0.9)    # setting up volume level  between 0 and 1

"""VOICE"""
voices = engine.getProperty('voices')       #getting details of current voice
engine.setProperty('voice', voices[0].id)  #changing index, changes voices. o for male
#engine.setProperty('voice', voices[3].id)   #changing index, changes voices. 1 for female

engine.say("Hello World!")
engine.say('My current speaking rate is ' + str(rate))
engine.runAndWait()
engine.stop()
# Out:
# 200
# 1.0

# %%
voices = engine.getProperty('voices') 
for voice in voices:
    # to get the info. about various voices in our PC 
    print("Voice:")
    print("ID: %s" %voice.id)
    print("Name: %s" %voice.name)
    print("Age: %s" %voice.age)
    print("Gender: %s" %voice.gender)
    print("Languages Known: %s" %voice.languages)
# Out:
# Voice:
# ID: HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_DAVID_11.0
# Name: Microsoft David Desktop - English (United States)
# Age: None
# Gender: None
# Languages Known: []
# Voice:
# ID: HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0
# Name: Microsoft Zira Desktop - English (United States)
# Age: None
# Gender: None
# Languages Known: []

# %%
import pyttsx3
engine = pyttsx3.init()
engine.setProperty('rate',160) 
engine.setProperty('voice', voices[2].id) 
engine.say("नमस्ते मैं आप सभी को वेबिनार के लिए आमंत्रित करता हूं")
engine.say("बिना प्रतीक्षा किए वेबिनार के लिए अभी रजिस्टर करें।")
engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28544/1201256788.py in <module>
#       2 engine = pyttsx3.init()
#       3 engine.setProperty('rate',160)
# ----> 4 engine.setProperty('voice', voices[2].id)
#       5 engine.say("नमस्ते मैं आप सभी को वेबिनार के लिए आमंत्रित करता हूं")
#       6 engine.say("बिना प्रतीक्षा किए वेबिनार के लिए अभी रजिस्टर करें।")
#
# IndexError: list index out of range

# %%
print(dir(pyttsx3))

# %%
#Speech to Text Conversion
duration=int(4)
#!pip install SpeechRecognition [Command to install SpeechRecognition package]
import speech_recognition as sr #Library for performing speech recognition with the Google Speech Recognition API.
r=sr.Recognizer()
with sr.Microphone() as source: # use the default microphone as the audio source
    print('Please Speak')
    r.pause_threshold=1 # pausing time
    audio=r.record(source,duration=duration)
    try:  # recognize speech using Google Speech Recognition
        text=r.recognize_google(audio,language='en-In').lower()
        print('\n'+text+'\n')
    except sr.UnknownValueError:           
        exit()
        
#NOTE: this requires PyAudio because it uses the Microphone class
# Out:
# Please Speak

# %%
#Speech to Text Conversion in hindi

#!pip install SpeechRecognition [Command to install SpeechRecognition package]
import speech_recognition as sr #Library for performing speech recognition with the Google Speech Recognition API.
r=sr.Recognizer()
with sr.Microphone() as source: # use the default microphone as the audio source
    print('Please Speak')
    r.pause_threshold=1 # pausing time
    r.adjust_for_ambient_noise(source,duration=1) #listen for 1 second to calibrate the energy threshold for ambient noise levels
    audio=r.record(source,duration=duration)  # now when we listen, the energy threshold is already set to a good value, and we can reliably catch speech right away
    try:  # recognize speech using Google Speech Recognition
        text=r.recognize_google(audio,language='hi-In').lower()
        print('\n'+text+'\n')
    except sr.UnknownValueError:           
        exit()
        
#NOTE: this requires PyAudio because it uses the Microphone class
# Out:
# Please Speak

# %%
import speech_recognition as sr
import pyttsx3
import datetime
import time

duration=int(4)
print('Loading your Personal Assitant - Galaxy')

engine=pyttsx3.init()
#voices=engine.getProperty('voices')
engine.setProperty('voice',voices[5].id)
engine.setProperty('rate',190) 

def speak(text):
    engine.say(text)
    engine.runAndWait()

def wishMe():
    hour=datetime.datetime.now().hour
    if hour>=0 and hour<12:
        speak("Hello,Good Morning")
        print("Hello,Good Morning")
    elif hour>=12 and hour<16:
        speak("Hello,Good Afternoon")
        print("Hello,Good Afternoon")
    else:
        speak("Hello,Good Evening")
        print("Hello,Good Evening")

def takeCommand():
    r=sr.Recognizer()
    with sr.Microphone() as source:
        print('Please Speak')
        r.pause_threshold=1 # pausing time
        print('listening')
        audio=r.record(source,duration=duration)
        print('decoding')
        try:
            statement=r.recognize_google(audio,language='en-In')
            print(f"user said:{statement}\n")
        except Exception as e:
            speak("Pardon me, please say that again")
            return "None"
        return statement

speak("Loading your voice assistant Galaxy")
wishMe()


if __name__=='__main__':


    while True:
        speak("Tell me how can I help you now?")
        statement = takeCommand().lower()
        if statement==0:
            continue

        if 'is your name' in statement:
            speak('My name is Galaxy and I was programmed to assist people around me.')
            
        if 'is your favorite color' in statement:
            speak(' my favorite color is Blue')
            
        elif "good bye" in statement or "ok bye" in statement or "stop" in statement:
            speak('your personal assistant Galaxy is shutting down,Good bye')
            print('your personal assistant Galaxy is shutting down,Good bye')
            break


        elif 'current time' in statement:
            strTime=datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"the time is {strTime}")

        elif 'who are you' in statement or 'what can you do' in statement:
            speak('I am Galaxy, your personal voice assistant. I am programmed to assist people around me'
                  'You can ask me questions like what is your name?, who made you?, what can you do?')


        elif "who made you" in statement or "who created you" in statement or "who discovered you" in statement:
            print("I was developed by Gagan Singh at Hex n bit")
            speak("I was developed by Gagan Singh at Hex n bit")
            



time.sleep(3)

# %%
#!pip install googletrans==4.0.0rc1
from googletrans import Translator
translator = Translator()
gi='आप क्या कर रहे हो'
print(translator.detect(gi))
text_to_translate = translator.translate(gi,dest= 'en', src= 'hi',)
             
# Storing the translated text in text
# variable
text = text_to_translate.text
print(text)

# %%
import speech_recognition as sr
import pyttsx3
import datetime
import time
import webbrowser

from googletrans import Translator
translator = Translator()

print('आपका व्यक्तिगत सहायक- गैलेक्सी लोड हो रहा है')

duration=int(4)
engine=pyttsx3.init()
voices=engine.getProperty('voices')
engine.setProperty('voice',voices[1].id)


def speak(text):
    engine.say(text)
    engine.runAndWait()

def wishMe():
    hour=datetime.datetime.now().hour
    if hour>=0 and hour<12:
        speak("सुप्रभात , आपका दिन शुभ हो")
        print("सुप्रभात , आपका दिन शुभ हो")
    elif hour>=12 and hour<16:
        speak("नमस्ते, आपका दिन शुभ हो")
        print("नमस्ते, आपका दिन शुभ हो")
    else:
        speak("नमस्ते, आपका दिन शुभ हो")
        print("नमस्ते, आपका दिन शुभ हो")

def takeCommand():
    r=sr.Recognizer()
    with sr.Microphone() as source:
        print('Please Speak')
        r.pause_threshold=1 # pausing time
        print('listening')
        audio=r.record(source,duration=duration)
        print('decoding')
        try:
            statement=r.recognize_google(audio,language='hi-In')
            print(f"user said:{statement}\n")
            text_to_translate = translator.translate(statement,dest= 'en', src= 'hi',)
            statement = text_to_translate.text
            print(statement)
            
        except Exception as e:
            speak("क्षमा करें, कृपया इसे फिर से कहें")
            return "None"
        
        return statement

speak("आपका व्यक्तिगत सहायक- गैलेक्सी लोड हो रहा है")
wishMe()


if __name__=='__main__':


     while True:
        speak("मुझे बताएं कि मैं आपकी कैसे मदद कर सकता हूं?")
        statement = takeCommand().lower()
        if statement==0:
            continue

        if 'is your name' in statement:
            speak('मेरा नाम गैलेक्सी है और मुझे अपने आसपास के लोगों की सहायता के लिए प्रोग्राम किया गया है')
            
        elif "good bye" in statement or "ok bye" in statement or "stop" in statement:
            speak('आपका निजी सहायक गैलेक्सी बंद हो रहा है, अलविदा')
            print('आपका निजी सहायक गैलेक्सी बंद हो रहा है, अलविदा')
            break


        elif 'what time' in statement or 'time' in statement:
            strTime=datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"समय है {strTime}")

        elif 'who are you' in statement or 'what can you do' in statement:
            speak('मैं गैलेक्सी हूं, आपका निजी आवाज सहायक। मुझे अपने आसपास के लोगों की सहायता के लिए प्रोग्राम किया गया है'
                  'आप मुझसे सवाल पूछ सकते हैं जैसे आपका नाम क्या है?, आपको किसने बनाया?, आप क्या कर सकते हैं?')


        elif "who made you" in statement or "who created you" in statement or "who discovered you" in statement:
            print("मैं गगन सिंह द्वारा हेक्स एन बिट में बनाया गया था")
            speak("मैं गगन सिंह द्वारा हेक्स एन बिट में बनाया गया था")
            
        elif 'favorite song' in statement:
            webbrowser.open_new_tab("https://www.youtube.com/watch?v=QqLyyDgLNdE")
            #speak("youtube is open now")
            time.sleep(5)



time.sleep(3)

# %%
import speech_recognition as sr
import pyttsx3
import datetime
import wikipedia
import webbrowser
import os
import time
import json
import requests

duration=int(4)
print('Loading your Personal Assitant - Galaxy')

engine=pyttsx3.init()
voices=engine.getProperty('voices')
engine.setProperty('voice',voices[4].id)
engine.setProperty('rate',190) 

def speak(text):
    engine.say(text)
    engine.runAndWait()

def wishMe():
    hour=datetime.datetime.now().hour
    if hour>=0 and hour<12:
        speak("Hello,Good Morning")
        print("Hello,Good Morning")
    elif hour>=12 and hour<16:
        speak("Hello,Good Afternoon")
        print("Hello,Good Afternoon")
    else:
        speak("Hello,Good Evening")
        print("Hello,Good Evening")

def takeCommand():
    r=sr.Recognizer()
    with sr.Microphone() as source:
        print('Please Speak')
        r.pause_threshold=1 # pausing time
        print('listening')
        audio=r.record(source,duration=duration)
        print('decoding')
        try:
            statement=r.recognize_google(audio,language='en-In')
            print(f"user said:{statement}\n")
        except Exception as e:
            speak("Pardon me, please say that again")
            return "None"
        return statement

speak("Loading your voice assistant Galaxy")
wishMe()


if __name__=='__main__':


    while True:
        speak("Tell me how can I help you now?")
        statement = takeCommand().lower()
        if statement==0:
            continue

        if 'is your name' in statement in statement:
            speak('My name is Galaxy and I was programmed to assist people around me.')
            
        elif "good bye" in statement or "ok bye" in statement or "stop" in statement:
            speak('your personal assistant Galaxy is shutting down,Good bye')
            print('your personal assistant Galaxy is shutting down,Good bye')
            break

        elif 'who are you' in statement or 'what can you do' in statement:
            speak('I am Galaxy, your personal voice assistant. I am programmed to assist people around me'
                  'You can ask me questions like what is your name?, who made you?, what can you do?')


        elif "who made you" in statement or "who created you" in statement or "who discovered you" in statement:
            print("I was developed by Gagan Singh at Hex n bit")
            speak("I was developed by Gagan Singh at Hex n bit")
            
        
        elif 'current time' in statement:
            strTime=datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"the time is {strTime}")
            
            
        elif 'wikipedia' in statement:
            speak('Searching Wikipedia...')
            statement =statement.replace("wikipedia", "")
            results = wikipedia.summary(statement, sentences=3)
            speak("According to Wikipedia")
            print(results)
            speak(results)

        elif 'open youtube' in statement:
            webbrowser.open_new_tab("https://www.youtube.com/")
            speak("youtube is open now")
            time.sleep(5)
            
        elif 'open main website' in statement:
            webbrowser.open_new_tab("https://www.hexnbit.com")
            speak("Hex N bit is open now")
            time.sleep(5)

        elif 'open google' in statement:
            webbrowser.open_new_tab("https://www.google.com")
            speak("Google chrome is open now")
            time.sleep(5)
            
            
        elif 'search google' in statement:
            speak("what you want to search")
            y=takeCommand()
            webbrowser.open_new("https://www.google.com/search?q="+y)
            time.sleep(5)

        elif 'open gmail' in statement:
            webbrowser.open_new_tab("gmail.com")
            speak("Google Mail open now")
            time.sleep(5)

        elif "weather" in statement:
            
            api_key='d36202bcb17d98b24e4b49b5f92a8a6e'

            base_url="https://api.openweathermap.org/data/2.5/weather?"
            speak("whats the city name")
            city_name=takeCommand()
            complete_url=base_url+"appid="+api_key+"&q="+city_name
            response = requests.get(complete_url)
            x=response.json()
            if x["cod"]!="404":
                y=x["main"]
                current_temperature = y["temp"]
                current_humidiy = y["humidity"]
                z = x["weather"]
                weather_description = z[0]["description"]
                speak(" Temperature in kelvin unit is " +
                      str(current_temperature) +
                      "\n humidity in percentage is " +
                      str(current_humidiy) +
                      "\n description  " +
                      str(weather_description))
                print(" Temperature in kelvin unit = " +
                      str(current_temperature) +
                      "\n humidity (in percentage) = " +
                      str(current_humidiy) +
                      "\n description = " +
                      str(weather_description))

            else:
                speak(" City Not Found ")
            
            
            
        elif "open stack overflow" in statement:
            webbrowser.open_new_tab("https://stackoverflow.com/")
            speak("Here is stackoverflow")

        elif 'news' in statement:
            news = webbrowser.open_new_tab("https://timesofindia.indiatimes.com/home/headlines")
            speak('Here are some headlines from the Times of India,Happy reading')
            time.sleep(6)


        elif 'search'  in statement:
            statement = statement.replace("search", "")
            webbrowser.open_new_tab(statement)
            time.sleep(5)

            

time.sleep(3)

# %%
import speech
speech.say('Hola mundo', 'es_ES')

# %%
import sound
r = sound.Recorder('audio.m4a')
r.record(3)

# %%
import win32com.client as wincl
speak=wincl.Dispatch("SAPI.SpVoice")
speak.Speak("Hello World!")
